# %%
import pandas as pd
df = pd.read_parquet('train-00000-of-00001.parquet','pyarrow')
# Out:
#                                             Question                 Answer  \
# 0  You are an expert chemist, your task is to pre...  <boolean>No</boolean>
# 1  You are an expert chemist, your task is to pre...  <boolean>No</boolean>
# 2  You are an expert chemist, your task is to pre...  <boolean>No</boolean>
# 3  You are an expert chemist, your task is to pre...  <boolean>No</boolean>
# 4  You are an expert chemist, your task is to pre...  <boolean>No</boolean>
#
#                                       TargetMolecule SampleMethod  SampleNum  \
# 0             COC(=O)C(C)N(C(=O)c1ccco1)c1c(C)cccc1C     scaffold          2
# 1                                     CCCc1ccc(N)cc1     scaffold          2
# 2  CN1[C@H]2C[C@H](OC(=O)[C@H](CO)c3ccccc3)C[C@@H...     scaffold          2
# 3                                    CCCC1CCC(=O)CC1     scaffold          2
# 4                                    CCCCNC(=S)NCCCC     scaffold          2
#
# ...
